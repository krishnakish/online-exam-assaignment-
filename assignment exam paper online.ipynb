# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_excel('E:\\R files\\raj python files\\external_links.xlsx')

# %%
data
# Out:
#                                                  title content  \
# 0    SQL at Scale with Apache Spark SQL and DataFra...
# 1    A Complete Machine Learning Walk-Through in Py...
# 2                 From ‘R vs Python’ to ‘R and Python’
# 3          Turn Python Scripts into Beautiful ML Tools
# 4                The case against the jupyter notebook
# ..                                                 ...     ...
# 634  IIHM eCHAT 2020 - IIHM Admission Process, Elig...
# 635  GATE 2020 CS (CSE) Subject Wise Marks, Percent...
# 636  NEET Predicted Question Paper 2020- Expected Q...
# 637  Who Will be Eligible for NATA 2020 - Detailed ...
# 638  CMAT Response Sheet 2020 - Dates, Details, How...
#
#                                                    url  \
# 0    https://towardsdatascience.com/sql-at-scale-wi...
# 1    https://towardsdatascience.com/a-complete-mach...
# 2    https://towardsdatascience.com/from-r-vs-pytho...
# 3    https://towardsdatascience.com/coding-ml-tools...
# ...

# %%
data.isnull().sum()
# Out:
# title               4
# content             4
# url                 4
# prev_cont           4
# prev_image          4
# date               56
# author_name       619
# author_link       619
# tags              615
# comments_cont     615
# comments_date     615
# comments_id       639
# Generated_tags     32
# dtype: int64

# %%
data.loc[222:,]
# Out:
#                                                  title content  \
# 222  WBJEE Result 2020 - Download Scorecard @ wbjee...
# 223  WBJEE 2020 Preparation Tips – Important Topics...
# 224                      How to prepare for WBJEE 2020
# 225  UPSEE Application Form 2020, Registration - Ap...
# 226  UPSEE 2020 - Application Form (JAN 27), Exam D...
# ..                                                 ...     ...
# 634  IIHM eCHAT 2020 - IIHM Admission Process, Elig...
# 635  GATE 2020 CS (CSE) Subject Wise Marks, Percent...
# 636  NEET Predicted Question Paper 2020- Expected Q...
# 637  Who Will be Eligible for NATA 2020 - Detailed ...
# 638  CMAT Response Sheet 2020 - Dates, Details, How...
#
#                                                    url  \
# 222  https://engineering.careers360.com/articles/wb...
# 223  https://engineering.careers360.com/articles/wb...
# 224  https://engineering.careers360.com/articles/ho...
# 225  https://engineering.careers360.com/articles/up...
# ...

# %%
data['prev_cont'].value_counts()
# Out:
# 3                                                                                                                                                                                                                                    20
# All the details about the Maharashtra MBA Admissions 2020 such as MBA entrance exams, eligibility, selection process, fees, important dates.                                                                                         10
# Low score in CMAT? Don't worry, we have got you covered! Check out this list of MBA colleges that accept low CMAT scores for admission.                                                                                               9
# Indian Institute of Management IIMC, Kolkata, 2020 Admission details Kolkata for MBA, PGPEx, PGDM. Check course wise admission process, selection criteria, merit list, application form dates, fees, eligibility, news and more.     7
# ...

# %%
data.shape
# Out:
# (639, 13)

# %%
data=data.drop(['title','content','url','prev_image','date','author_name','author_link','tags','comments_cont','comments_date','comments_id'],axis=1)

# %%
data.head()
# Out:
#                                            prev_cont  \
# 0  Wrangle, aggregate, filter data at scale using...
# 1       Putting the machine learning pieces together
# 2  Choosing Programming language based on your ne...
# 3  Introducing Streamlit, an app framework built ...
# 4                       Joel Grus on the TDS podcast
#
#                                       Generated_tags
# 0  e,concepts,at,dataframe,friend,n,c,sql,r,apach...
# 1               e,n,learning,c,r,complete,python,com
# 2  e,at,n,c,language,lang,r,os,base,programming,d...
# 3         e,n,ip,c,tools,r,ui,script,stream,d,python
# 4                               e,n,c,jupyter,r,d,ai

# %%
data.isnull().sum()
# Out:
# prev_cont          4
# Generated_tags    32
# dtype: int64

# %%
x=data['prev_cont']

# %%
y=data['Generated_tags']

# %%
x
# Out:
# 0      Wrangle, aggregate, filter data at scale using...
# 1           Putting the machine learning pieces together
# 2      Choosing Programming language based on your ne...
# 3      Introducing Streamlit, an app framework built ...
# 4                           Joel Grus on the TDS podcast
#                              ...
# 634    Applications are open for the IIHM eCHAT 2020....
# 635    GATE CS 2020 subject wise weightage, questions...
# 636    We have come up with NEET predicted question p...
# 637    NATA 2020 will be conducted on 19 April and 31...
# 638    Need all of the important information regardin...
# Name: prev_cont, Length: 639, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

cv = TfidfVectorizer()

X = cv.fit_transform(data)

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels=kmeans.labels_
labels
# Out:
# array([0, 1])

# %%
centroids=kmeans.cluster_centers_
centroids
# Out:
# array([[0., 1.],
#        [1., 0.]])

# %%
pd.crosstab(kmeans,labels)
# Out:
# col_0                                               0  1
# row_0
# KMeans(algorithm='auto', copy_x=True, init='k-m...  1  1

# %%
X.shape
# Out:
# (2, 2)
